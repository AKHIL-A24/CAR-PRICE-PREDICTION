# %% [markdown]
# EDA Plan for Car Price Dataset

# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r'D:\DATA_SCIENCE\DATASET\CarPrice_Assignment.csv')
print(df)
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %% [markdown]
# Dataset Overview

# %%
df.shape
df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# Statistical Summary

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# Missing Values Check

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# Remove Unnecessary Columns

# %%
df.drop(['car_ID'], axis=1, inplace=True)

# %% [markdown]
# Extract Car Brand

# %%
df['brand'] = df['CarName'].apply(lambda x: x.split(' ')[0])
df.drop(['CarName'], axis=1, inplace=True)

# %% [markdown]
# Identify Categorical & Numerical Columns

# %%
categorical = df.select_dtypes(include='object').columns
numerical = df.select_dtypes(exclude='object').columns

# %% [markdown]
# Univariate Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['price'], kde=True)
plt.show()

# %% [markdown]
# Correlation Analysis

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.show()
# Out:
# C:\Users\moidu\AppData\Local\Temp\ipykernel_19076\1115454827.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap="coolwarm")

# %% [markdown]
# Feature vs Price Analysis

# %%
##Engine Size vs Price

sns.scatterplot(x='enginesize', y='price', data=df)
plt.show()

# %%
##Horsepower vs Price

sns.scatterplot(x='horsepower', y='price', data=df)
plt.show()

# %%
## Curbweight vs Price

sns.scatterplot(x='curbweight', y='price', data=df)
plt.show()

# %% [markdown]
# Categorical Feature Analysis

# %%
## Fuel Type

sns.barplot(x='fueltype', y='price', data=df)
plt.show()

# %% [markdown]
# Brand vs Price

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='brand', y='price', data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# MPG Analysis

# %%
sns.scatterplot(x='citympg', y='price', data=df)
sns.scatterplot(x='highwaympg', y='price', data=df)
# Out:
# <Axes: xlabel='citympg', ylabel='price'>

# %% [markdown]
# Outlier Detection

# %%
sns.boxplot(df['price'])
plt.show()

# %% [markdown]
# Feature Importance Preparation

# %%
df = pd.get_dummies(df, drop_first=True)

# %% [markdown]
# Drop Unnecessary Columns

# %%
df.drop(['car_ID','CarName'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.drop(['car_ID','CarName'], axis=1, inplace=True)
#
# File c:\Users\moidu\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\moidu\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
# ...

# %% [markdown]
# Convert Categorical Data

# %%
df = pd.get_dummies(df, drop_first=True)

# %% [markdown]
# Final Dataset for ML

# %%
X = df.drop('price', axis=1)
y = df['price']

# %% [markdown]
# # START THE ML

# %% [markdown]
# Multiple Linear Regression

# %%
# Train Test Split

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
# Train Multiple Linear Regression

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Predict

y_pred = model.predict(X_test)

# %%
# Accuracy (R² Score)

from sklearn.metrics import r2_score
accuracy = r2_score(y_test,y_pred)
print("Accuracy:",accuracy*100)
# Out:
# Accuracy: 88.74556036341077

# %% [markdown]
# Polynomial Regression

# %%
# Import Polynomial Features

from sklearn.preprocessing import PolynomialFeatures

# %%
# Create Polynomial Features

poly = PolynomialFeatures(degree=2)

X_poly_train = poly.fit_transform(X_train)
X_poly_test = poly.transform(X_test)

# %%
# Train Model

model2 = LinearRegression()
model2.fit(X_poly_train,y_train)
# Out:
# LinearRegression()

# %%
# Predict

y_pred_poly = model2.predict(X_poly_test)

# %%
# Accuracy

print("Multiple Linear Regression:",accuracy*100)
# Out:
# Multiple Linear Regression: 88.74556036341077

# %%
plt.scatter(y_test,y_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.show()

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# Multiple Linear Regression shows that car price mainly depends on features like engine size, horsepower, and curb weight.
#
# Polynomial Regression captures non-linear patterns and usually gives better prediction accuracy than linear regression.

# %% [markdown]
# ### JUST GPT TRY CODE BELOW

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# Load Dataset
df = pd.read_csv(r'D:\DATA_SCIENCE\DATASET\CarPrice_Assignment.csv')
print(df)

# Select Feature and Target
X = df[['enginesize']]
y = df['price']

# -------------------------
# Linear Regression
# -------------------------
linear_model = LinearRegression()
linear_model.fit(X, y)

y_pred_linear = linear_model.predict(X)

# -------------------------
# Polynomial Regression
# -------------------------
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

poly_model = LinearRegression()
poly_model.fit(X_poly, y)

y_pred_poly = poly_model.predict(X_poly)

# -------------------------
# Visualization
# -------------------------
plt.figure(figsize=(10,6))

# Actual data
plt.scatter(X, y)

# Linear Regression Line
plt.plot(X, y_pred_linear)

# Polynomial Curve
sorted_zip = sorted(zip(X.values.flatten(), y_pred_poly))
X_sorted, y_poly_sorted = zip(*sorted_zip)
plt.plot(X_sorted, y_poly_sorted)

plt.title("Linear vs Polynomial Regression")
plt.xlabel("Engine Size")
plt.ylabel("Car Price")

plt.show()
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...
